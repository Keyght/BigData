# %%
import numpy as np

a1 = [80, 98, 75, 91, 78]
a2 = [100, 82, 105, 89, 102]

np.corrcoef(a1, a2)[0,1]
# Out:
# -0.9999999999999998

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(5,5))
plt.grid(True)
plt.title('Диапазон рассеяния', fontsize=20)
plt.xlabel('Число машин на улице')
plt.ylabel('Число машин в гараже')
plt.scatter(a1,a2,marker='o',color='crimson')
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
import pandas as pd
s = pd.read_csv("bitcoin.csv")

# %%
s1=s[0:len(s)-14]
# Out:
#       Unnamed: 0        time      high       low      open  volumefrom  \
# 0              0  2015-12-20    462.76    431.10    461.20   121531.64
# 1              1  2015-12-21    445.54    423.99    441.78   121990.88
# 2              2  2015-12-22    443.22    433.25    437.59    65785.54
# 3              3  2015-12-23    444.78    434.28    437.03    63247.04
# 4              4  2015-12-24    460.62    441.76    442.43    79604.01
# ...          ...         ...       ...       ...       ...         ...
# 1982        1982  2021-05-24  39945.35  34467.32  34716.84   106765.14
# 1983        1983  2021-05-25  39842.90  36509.09  38837.76    66530.67
# 1984        1984  2021-05-26  40854.81  37855.81  38387.36    66483.59
# 1985        1985  2021-05-27  40408.95  37211.84  39295.08    46474.62
# 1986        1986  2021-05-28  38879.60  34733.76  38538.84    85345.66
#
#           volumeto     close
# 0     5.431648e+07    441.78
# 1     5.327022e+07    437.59
# ...

# %%
y = s1['close']
x = s1['Unnamed: 0']

n = np.size(x)

m_x = np.mean(x)
m_y = np.mean(y)

SS_xy = np.sum(y*x) - n*m_x*m_y
SS_xx = np.sum(x*x) - n*m_x*m_x

b_1 = SS_xy / SS_xx
b_0 = m_y - b_1*m_x

b = (b_0, b_1)
print(b)
fig2 = plt.figure(figsize=(9,6))

x=x[1750:len(x)]
y=y[1750:len(y)]
plt.scatter(x,y, color="m", marker="o", s = 30)
plt.vlines(n,0,60000, color="r")

x = s['Unnamed: 0']
y_pred=b[0]+b[1]*x
y_pred_copy=y_pred

x = x[1750:len(x)]
y_pred = y_pred[1750:len(y_pred)]

plt.plot(x, y_pred, color = "g")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# (-4967.451288364324, 14.279139036151857)
# <img src="data:image/png;base64,..." width="900">

# %%
import math
x1 =x[-14:len(x)]
y1=y_pred[-14:len(y_pred)]
y2=s['close'][-14:len(s['close'])]
e=0
u=0
for i in x1:
    e+=y2[i]-y1[i]
    u+=y2[i]-np.mean(y1)
r = math.sqrt(1 - (e*e)/(u*u))
print(r)
# Out:
# 1.8250120749944284e-08

# %%
print('Угол наклона: ', math.degrees(math.atan(b[1])))
print('Перехват: ', b[0])
# Out:
# Угол наклона:  85.9939892219565
# Перехват:  -4967.451288364324

# %%
fig3 = plt.figure(figsize=(9,6))
plt.grid(True)
plt.title('Диапазон рассеяния', fontsize=20)
plt.xlabel('Значения линейной регрессии')
plt.ylabel('Исходные значения')
plt.scatter(y_pred_copy, s['close'], marker='o', color='crimson')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
s1 = pd.read_csv("housePrice.csv")

# %%
s1 = s1.drop([570,709,807,1604,2171,2802])

# %%
y = s1['Price(USD)']
x = s1['Area'].astype(float)

n = np.size(x)

m_x = np.mean(x)
m_y = np.mean(y)

SS_xy = np.sum(y*x) - n*m_x*m_y
SS_xx = np.sum(x*x) - n*m_x*m_x

b_1 = SS_xy / SS_xx
b_0 = m_y - b_1*m_x

b = (b_0, b_1)
print(b)
fig2 = plt.figure(figsize=(9,6))

plt.scatter(x,y, color="m", marker="o", s = 30)
plt.vlines(n,0,60000, color="r")

x = s['Unnamed: 0']
y_pred=b[0]+b[1]*x


plt.plot(x, y_pred, color = "g")
plt.grid(True)
plt.xlabel('Price')
plt.ylabel('Area')
plt.show()
# Out:
# (-122003.4867495785, 2814.2556027896635)
# <img src="data:image/png;base64,..." width="900">

# %%
print('Угол наклона: ', math.degrees(math.atan(b[1])))
print('Перехват: ', b[0])
# Out:
# Угол наклона:  89.97964087659811
# Перехват:  -122003.4867495785
