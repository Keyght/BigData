# %%
import numpy as np

a1 = [80, 98, 75, 91, 78]
a2 = [100, 82, 105, 89, 102]

np.corrcoef(a1, a2)[0,1]
# Out:
# -0.9999999999999998

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(5,5))
plt.grid(True)
plt.title('Диапазон рассеяния', fontsize=20)
plt.xlabel('Число машин на улице')
plt.ylabel('Число машин в гараже')
plt.scatter(a1,a2,marker='o',color='crimson')

# %%
import pandas as pd
s = pd.read_csv("bitcoin.csv")

# %%
s1=s[0:len(s)-14]

# %%
from sklearn.linear_model import LinearRegression

y = s1['close']
x = s1['Unnamed: 0']

n = len(x)

x = np.array(x, type(float))
y = np.array(y, type(float))

fig2 = plt.figure(figsize=(9,6))
regression = LinearRegression()
regression.fit(x.reshape(-1,1),y)

plt.scatter(x,y, color="m", marker="o", s = 30)

plt.plot(x, regression.predict(x.reshape(-1,1)), color = "g")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import math
x1=x[-14:len(x)]
y1=regression.predict(x.reshape(-1,1))[-14:len(regression.predict(x.reshape(-1,1)))]
y2=y[-14:len(y)]
e=0
u=0
for i in range(len(x)-1):
    e+=y2[i]-y1[i]
    u+=y2[i]-np.mean(y1)
r = math.sqrt(1 - (e*e)/(u*u))
print(r)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [66], in <cell line: 7>()
#       6 u=0
#       7 for i in range(len(x)-1):
# ----> 8     e+=y2[i]-y1[i]
#       9     u+=y2[i]-np.mean(y1)
#      10 r = math.sqrt(1 - (e*e)/(u*u))
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
print('Угол наклона: ', math.degrees(math.atan(b[1])))
print('Перехват: ', b[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 print('Угол наклона: ', math.degrees(math.atan(b[1])))
#       2 print('Перехват: ', b[0])
#
# NameError: name 'b' is not defined

# %%
fig3 = plt.figure(figsize=(9,6))
plt.grid(True)
plt.title('Диапазон рассеяния', fontsize=20)
plt.xlabel('Значения линейной регрессии')
plt.ylabel('Исходные значения')
plt.scatter(y_pred_copy, s['close'], marker='o', color='crimson')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 6>()
#       4 plt.xlabel('Значения линейной регрессии')
#       5 plt.ylabel('Исходные значения')
# ----> 6 plt.scatter(y_pred_copy, s['close'], marker='o', color='crimson')
#
# NameError: name 'y_pred_copy' is not defined

# %%
s1 = pd.read_csv("housePrice.csv")

# %%
s1 = s1.drop([570,709,807,1604,2171,2802])

# %%
y = s1['Price(USD)']
x = s1['Area'].astype(float)

n = np.size(x)

m_x = np.mean(x)
m_y = np.mean(y)

SS_xy = np.sum(y*x) - n*m_x*m_y
SS_xx = np.sum(x*x) - n*m_x*m_x

b_1 = SS_xy / SS_xx
b_0 = m_y - b_1*m_x

b = (b_0, b_1)
print(b)
fig2 = plt.figure(figsize=(9,6))

plt.scatter(x,y, color="m", marker="o", s = 30)
plt.vlines(n,0,60000, color="r")

x = s['Unnamed: 0']
y_pred=b[0]+b[1]*x


plt.plot(x, y_pred, color = "g")
plt.grid(True)
plt.xlabel('Price')
plt.ylabel('Area')
plt.show()

# %%
print('Угол наклона: ', math.degrees(math.atan(b[1])))
print('Перехват: ', b[0])
